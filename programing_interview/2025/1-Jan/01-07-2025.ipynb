# %% [markdown]
# ## Input: words = ["mass","as","hero","superhero"]
# ## Output: ["as","hero"]

# %%
words = ["leetcoder","leetcode","od","hamlet","am"]

new_list = []
for i in range(len(words)):
    for j in range(len(words)):
        if i == j:
            continue
        if words[i] in words[j]:
            new_list.append(words[i])
            break

print(new_list)
# Out:
# ['leetcode', 'od', 'am']

# %%
{
    "entities": [
        {
            "EntityInfo": {
                "id": "cf0286c3-8564-4f52-80d2-1611b217f277",
                "created_at": "2025-01-08T18:19:52.056972Z",
                "updated_at": "2025-01-08T18:19:52.056972Z",
                "deleted_at": null,
                "owner_id": 1,
                "name": "owner-1-entity-1",
                "csid": "4245ae33b-e5a3-4c15-af7e-fe578d8423a6",
                "type": "site",
                "metadata": "New Switch entity",
                "service_owner": "iam",
                "tags": null
            },
            "tag": [
                {
                    "id": "43d2002b-864f-41ec-afea-f9a3a930d034",
                    "created_at": "2025-01-08T18:20:05.340019Z",
                    "updated_at": "2025-01-08T18:20:05.340019Z",
                    "deleted_at": null,
                    "owner_id": 1,
                    "name": "owner-1-tag-1",
                    "type": "auto",
                    "description": "lab-device tag",
                    "service_owner": "network",
                    "access": "read",
                    "parent": "3b4c5d6e-7890-12ab-cdef-4567890abcde",
                    "policy_name": "",
                    "entities": null,
                    "policy": null
                }
            ]
        },
        {
            "EntityInfo": {
                "id": "8fedace5-d35a-4f07-bf1a-c94b4a0897ae",
                "created_at": "2025-01-08T18:19:52.056972Z",
                "updated_at": "2025-01-08T18:19:52.056972Z",
                "deleted_at": null,
                "owner_id": 1,
                "name": "owner-1-entity-2",
                "csid": "4245ae33b-e5a3-4c15-af7e-fe578d8423a6",
                "type": "site",
                "metadata": "New Switch entity",
                "service_owner": "iam",
                "tags": null
            },
            "tag": [
                {
                    "id": "43d2002b-864f-41ec-afea-f9a3a930d034",
                    "created_at": "2025-01-08T18:20:05.340019Z",
                    "updated_at": "2025-01-08T18:20:05.340019Z",
                    "deleted_at": null,
                    "owner_id": 1,
                    "name": "owner-1-tag-1",
                    "type": "auto",
                    "description": "lab-device tag",
                    "service_owner": "network",
                    "access": "read",
                    "parent": "3b4c5d6e-7890-12ab-cdef-4567890abcde",
                    "policy_name": "",
                    "entities": null,
                    "policy": null
                },
                {
                    "id": "43d2002b-864f-41ec-afea-f9a3a930d034",
                    "created_at": "2025-01-08T18:20:05.340019Z",
                    "updated_at": "2025-01-08T18:20:05.340019Z",
                    "deleted_at": null,
                    "owner_id": 1,
                    "name": "owner-1-tag-1",
                    "type": "auto",
                    "description": "lab-device tag",
                    "service_owner": "network",
                    "access": "read",
                    "parent": "3b4c5d6e-7890-12ab-cdef-4567890abcde",
                    "policy_name": "",
                    "entities": null,
                    "policy": null
                }
            ]
        },
        {
            "EntityInfo": {
                "id": "956a8460-32cb-4055-b4d9-2c9c7ff0586c",
                "created_at": "2025-01-08T18:19:52.056972Z",
                "updated_at": "2025-01-08T18:19:52.056972Z",
                "deleted_at": null,
                "owner_id": 1,
                "name": "owner-1-entity-3",
                "csid": "4245ae33b-e5a3-4c15-af7e-fe578d8423a6",
                "type": "site",
                "metadata": "New Switch entity",
                "service_owner": "iam",
                "tags": null
            },
            "tag": [
                {
                    "id": "43d2002b-864f-41ec-afea-f9a3a930d034",
                    "created_at": "2025-01-08T18:20:05.340019Z",
                    "updated_at": "2025-01-08T18:20:05.340019Z",
                    "deleted_at": null,
                    "owner_id": 1,
                    "name": "owner-1-tag-1",
                    "type": "auto",
                    "description": "lab-device tag",
                    "service_owner": "network",
                    "access": "read",
                    "parent": "3b4c5d6e-7890-12ab-cdef-4567890abcde",
                    "policy_name": "",
                    "entities": null,
                    "policy": null
                },
                {
                    "id": "43d2002b-864f-41ec-afea-f9a3a930d034",
                    "created_at": "2025-01-08T18:20:05.340019Z",
                    "updated_at": "2025-01-08T18:20:05.340019Z",
                    "deleted_at": null,
                    "owner_id": 1,
                    "name": "owner-1-tag-1",
                    "type": "auto",
                    "description": "lab-device tag",
                    "service_owner": "network",
                    "access": "read",
                    "parent": "3b4c5d6e-7890-12ab-cdef-4567890abcde",
                    "policy_name": "",
                    "entities": null,
                    "policy": null
                },
                {
                    "id": "43d2002b-864f-41ec-afea-f9a3a930d034",
                    "created_at": "2025-01-08T18:20:05.340019Z",
                    "updated_at": "2025-01-08T18:20:05.340019Z",
                    "deleted_at": null,
                    "owner_id": 1,
                    "name": "owner-1-tag-1",
                    "type": "auto",
                    "description": "lab-device tag",
                    "service_owner": "network",
                    "access": "read",
                    "parent": "3b4c5d6e-7890-12ab-cdef-4567890abcde",
                    "policy_name": "",
                    "entities": null,
                    "policy": null
                }
            ]
        }
    ]
}
